# %%
import pandas as pd

# %%
master_items = pd.read_json('MasterItems_split.json') #split removd the first "MasterItems" = { } so the content addresses are the columns by default now
display(master_items.iloc[:5])
print(master_items.columns)
# Out:
#                    content/items/weapons/player/skins/combataxe/combataxe_p1_s001  \
# material_overrides                                                 {}
# slots                              {'1': 'slot_weapon_skin (string)'}
# item_type                                        WEAPON_SKIN (string)
# name                content/items/weapons/player/skins/combataxe/c...
# preview_item        content/items/weapons/player/melee/combataxe_p...
#
#                    content/items/characters/player/eye_colors/eye_color_psyker_01_black_scalera  \
# material_overrides     {'1': 'eyes_psyker_01_black_scalera (string)'}
# slots                           {'1': 'slot_body_eye_color (string)'}
# item_type                                          EYE_COLOR (string)
# name                content/items/characters/player/eye_colors/eye...
# preview_item                                                      NaN
#
#                    content/items/weapons/player/melee/blades/falchion_blade_05  \
# material_overrides                                                 {}
# slots                                                             NaN
# item_type                                                         NaN
# name                content/items/weapons/player/melee/blades/falc...
# preview_item                                                      NaN
#
#                    content/items/characters/player/human/gear_lowerbody/cadian_d_lowerbody_set_05  \
# material_overrides                   {'1': 'coated_wear_04 (string)'}
# slots                           {'1': 'slot_gear_lowerbody (string)'}
# item_type                                     GEAR_LOWERBODY (string)
# name                content/items/characters/player/human/gear_low...
# preview_item                                                      NaN
#
#                    content/items/traits/bespoke_bolter_p1/stacking_power_bonus_on_staggering_enemies  \
# material_overrides                                                NaN
# slots                                                             NaN
# item_type                                              TRAIT (string)
# name                content/items/traits/bespoke_bolter_p1/stackin...
# preview_item                                                      NaN
#
#                    content/items/characters/minions/chaos_ogryn/attachments_base/skin_attachment_02  \
# material_overrides                                                 {}
# slots                                                             NaN
# item_type                                                         NaN
# name                content/items/characters/minions/chaos_ogryn/a...
# preview_item                                                      NaN
#
#                    content/items/traits/bespoke_thumper_p1/suppression_on_close_kill  \
# material_overrides                                                NaN
# slots                                                             NaN
# item_type                                              TRAIT (string)
# name                content/items/traits/bespoke_thumper_p1/suppre...
# preview_item                                                      NaN
#
#                    content/items/characters/player/human/gear_head/imperial_guard_upperbody_a_05_headgear_set_03  \
# material_overrides  {'1': 'fabric_cotton_01_wear_02 (string)', '2'...
# slots                                {'1': 'slot_gear_head (string)'}
# item_type                                          GEAR_HEAD (string)
# name                content/items/characters/player/human/gear_hea...
# preview_item                                                      NaN
#
#                    content/items/characters/player/human/gear_legs/astra_pants_d  \
# material_overrides                                                 {}
# slots                                {'1': 'slot_gear_legs (string)'}
# item_type                                                         NaN
# name                content/items/characters/player/human/gear_leg...
# preview_item                                                      NaN
#
#                    content/items/weapons/player/melee/blades/chain_axe_blade_03  \
# material_overrides                                                 {}
# slots                                                             NaN
# item_type                                                         NaN
# name                content/items/weapons/player/melee/blades/chai...
# preview_item                                                      NaN
#
#                     ...  \
# material_overrides  ...
# slots               ...
# item_type           ...
# name                ...
# preview_item        ...
#
#                    content/items/characters/player/ogryn/face_scars/ogryn_scar_face_28  \
# material_overrides                                                NaN
# slots                           {'1': 'slot_body_face_scar (string)'}
# item_type                                          FACE_SCAR (string)
# name                content/items/characters/player/ogryn/face_sca...
# preview_item                                                      NaN
#
#                              content/items/curios/devices/device_k_02  \
# material_overrides                                                NaN
# slots                                                             NaN
# item_type                                                         NaN
# name                content/items/curios/devices/device_k_02 (string)
# preview_item                                                      NaN
#
#                    content/items/weapons/player/skins/ogryn_heavystubber/ogryn_heavystubber_p1_ps003  \
# material_overrides                                                 {}
# slots                              {'1': 'slot_weapon_skin (string)'}
# item_type                                        WEAPON_SKIN (string)
# name                content/items/weapons/player/skins/ogryn_heavy...
# preview_item        content/items/weapons/player/ranged/ogryn_heav...
#
#                    content/items/characters/minions/chaos_traitor_guard/attachments_gear/newly_infected_lowerbody_c_var_wt_03  \
# material_overrides            {'1': 'cloth_variation_wt_03 (string)'}
# slots                                                             NaN
# item_type                                                         NaN
# name                content/items/characters/minions/chaos_traitor...
# preview_item                                                      NaN
#
#                    content/items/characters/minions/chaos_traitor_guard/attachments_gear/newly_infected_lowerbody_c_var_wt_06  \
# material_overrides            {'1': 'cloth_variation_wt_06 (string)'}
# slots                                                             NaN
# item_type                                                         NaN
# name                content/items/characters/minions/chaos_traitor...
# preview_item                                                      NaN
#
#                    content/items/characters/player/human/gear_lowerbody/veteran_lowerbody_career_02_lvl_02_set_01  \
# material_overrides                                                 {}
# slots                           {'1': 'slot_gear_lowerbody (string)'}
# item_type                                     GEAR_LOWERBODY (string)
# name                content/items/characters/player/human/gear_low...
# preview_item                                                      NaN
#
#                    content/items/characters/player/human/gear_torso/npc_upperbody_a  \
# material_overrides                                                 {}
# slots                               {'1': 'slot_gear_torso (string)'}
# item_type                                                         NaN
# name                content/items/characters/player/human/gear_tor...
# preview_item                                                      NaN
#
#                    content/items/characters/player/human/gear_head/savlar_chem_dogs_01_b_var_01  \
# material_overrides  {'2': 'coated_wear_04 (string)', '1': 'fabric_...
# slots                                {'1': 'slot_gear_head (string)'}
# item_type                                          GEAR_HEAD (string)
# name                content/items/characters/player/human/gear_hea...
# preview_item                                                      NaN
#
#                    content/items/characters/player/human/gear_lowerbody/veteran_lowerbody_career_01_lvl_05_set_03  \
# material_overrides                                                 {}
# slots                           {'1': 'slot_gear_lowerbody (string)'}
# item_type                                     GEAR_LOWERBODY (string)
# name                content/items/characters/player/human/gear_low...
# preview_item                                                      NaN
#
#                    content/items/characters/minions/chaos_traitor_guard/attachments_gear/newly_infected_upperbody_a_var_wt_06
# material_overrides            {'1': 'cloth_variation_wt_06 (string)'}
# slots                                                             NaN
# item_type                                                         NaN
# name                content/items/characters/minions/chaos_traitor...
# preview_item                                                      NaN
#
# [5 rows x 5453 columns]
# Index(['content/items/weapons/player/skins/combataxe/combataxe_p1_s001',
#        'content/items/characters/player/eye_colors/eye_color_psyker_01_black_scalera',
#        'content/items/weapons/player/melee/blades/falchion_blade_05',
#        'content/items/characters/player/human/gear_lowerbody/cadian_d_lowerbody_set_05',
#        'content/items/traits/bespoke_bolter_p1/stacking_power_bonus_on_staggering_enemies',
#        'content/items/characters/minions/chaos_ogryn/attachments_base/skin_attachment_02',
#        'content/items/traits/bespoke_thumper_p1/suppression_on_close_kill',
#        'content/items/characters/player/human/gear_head/imperial_guard_upperbody_a_05_headgear_set_03',
#        'content/items/characters/player/human/gear_legs/astra_pants_d',
#        'content/items/weapons/player/melee/blades/chain_axe_blade_03',
#        ...
#        'content/items/characters/player/ogryn/face_scars/ogryn_scar_face_28',
#        'content/items/curios/devices/device_k_02',
#        'content/items/weapons/player/skins/ogryn_heavystubber/ogryn_heavystubber_p1_ps003',
#        'content/items/characters/minions/chaos_traitor_guard/attachments_gear/newly_infected_lowerbody_c_var_wt_03',
#        'content/items/characters/minions/chaos_traitor_guard/attachments_gear/newly_infected_lowerbody_c_var_wt_06',
#        'content/items/characters/player/human/gear_lowerbody/veteran_lowerbody_career_02_lvl_02_set_01',
#        'content/items/characters/player/human/gear_torso/npc_upperbody_a',
#        'content/items/characters/player/human/gear_head/savlar_chem_dogs_01_b_var_01',
#        'content/items/characters/player/human/gear_lowerbody/veteran_lowerbody_career_01_lvl_05_set_03',
#        'content/items/characters/minions/chaos_traitor_guard/attachments_gear/newly_infected_upperbody_a_var_wt_06'],
#       dtype='object', length=5453)

# %%
# match all if it starts with
# m: melee
# r: ranged
master_items_attachments_only = master_items.filter(regex='content/items/weapons/player/[mr].*')
# print first 5 columns as test
display(master_items_attachments_only.iloc[:, 0:5])

display(master_items_attachments_only.loc['attach_node'])
# Out:
#                      content/items/weapons/player/melee/blades/falchion_blade_05  \
# material_overrides                                                   {}
# slots                                                               NaN
# item_type                                                           NaN
# name                  content/items/weapons/player/melee/blades/falc...
# preview_item                                                        NaN
# ...                                                                 ...
# preview_unit                                                        NaN
# available_base_stats                                                NaN
# available_overclocks                                                NaN
# set_items                                                           NaN
# breed_attach_node                                                   NaN
#
#                      content/items/weapons/player/melee/blades/chain_axe_blade_03  \
# material_overrides                                                   {}
# slots                                                               NaN
# item_type                                                           NaN
# name                  content/items/weapons/player/melee/blades/chai...
# preview_item                                                        NaN
# ...                                                                 ...
# preview_unit                                                        NaN
# available_base_stats                                                NaN
# available_overclocks                                                NaN
# set_items                                                           NaN
# breed_attach_node                                                   NaN
#
#                      content/items/weapons/player/ranged/recievers/autogun_rifle_ak_receiver_01  \
# material_overrides                                                  NaN
# slots                                                               NaN
# item_type                                                           NaN
# name                  content/items/weapons/player/ranged/recievers/...
# preview_item                                                        NaN
# ...                                                                 ...
# preview_unit                                                        NaN
# available_base_stats                                                NaN
# available_overclocks                                                NaN
# set_items                                                           NaN
# breed_attach_node                                                   NaN
#
#                      content/items/weapons/player/ranged/grips/autogun_rifle_grip_ak_01  \
# material_overrides                                                  NaN
# slots                                                               NaN
# item_type                                                           NaN
# name                  content/items/weapons/player/ranged/grips/auto...
# preview_item                                                        NaN
# ...                                                                 ...
# preview_unit                                                        NaN
# available_base_stats                                                NaN
# available_overclocks                                                NaN
# set_items                                                           NaN
# breed_attach_node                                                   NaN
#
#                       content/items/weapons/player/ranged/grips/grip_03
# material_overrides                                                  NaN
# slots                                                               NaN
# item_type                                                           NaN
# name                  content/items/weapons/player/ranged/grips/grip...
# preview_item                                                        NaN
# ...                                                                 ...
# preview_unit                                                        NaN
# available_base_stats                                                NaN
# available_overclocks                                                NaN
# set_items                                                           NaN
# breed_attach_node                                                   NaN
#
# [84 rows x 5 columns]
# content/items/weapons/player/melee/blades/falchion_blade_05                                  ap_blade_01 (string)
# content/items/weapons/player/melee/blades/chain_axe_blade_03                                 ap_blade_01 (string)
# content/items/weapons/player/ranged/recievers/autogun_rifle_ak_receiver_01     rp_autogun_ak_chained_rig (string)
# content/items/weapons/player/ranged/grips/autogun_rifle_grip_ak_01                            ap_grip_01 (string)
# content/items/weapons/player/ranged/grips/grip_03                                             ap_grip_01 (string)
#                                                                                              ...
# content/items/weapons/player/melee/ogryn_powermaul_p1_empty_base                     j_rightweaponattach (string)
# content/items/weapons/player/melee/grips/force_sword_grip_03                  rp_force_sword_chained_rig (string)
# content/items/weapons/player/melee/heads/2h_power_maul_head_05                                ap_head_01 (string)
# content/items/weapons/player/ranged/bayonets/bayonet_01                                    ap_bayonet_01 (string)
# content/items/weapons/player/ranged/sights/lasgun_rifle_sight_01                             ap_sight_01 (string)
# Name: attach_node, Length: 788, dtype: object

# %%
# creates a series with only address and attach_nodes
#   Series
MI_attach_nodes = master_items_attachments_only.loc['attach_node']
# filter to only unique entries
#   Array
MI_attach_nodes = MI_attach_nodes.unique()
MI_attach_nodes = sorted(MI_attach_nodes)

# Using open() function
file_path = 'weapon_attachments_list_of_attach_nodes.txt'

# Open the file in write mode
with open(file_path, 'w') as file:
    for node in MI_attach_nodes:
        # strip the string identifier part
        node = node.replace(' (string)', '')
        file.write(node+'\n')
        print(node)
# Out:
# 1
# ap_anim_02
# ap_anim_03
# ap_anim_04
# ap_anim_05
# ap_barrel_01
# ap_bayonet_01
# ap_blade_01
# ap_body_01
# ap_bullet_01
# ap_bullet_02
# ap_chain_01
# ap_connector_01
# ap_emblem_left
# ap_emblem_right
# ap_flashlight_01
# ap_grip_01
# ap_handle_01
# ap_head_01
# ap_hilt_01
# ap_magazine_01
# ap_magazine_02
# ap_muzzle_01
# ap_pommel_01
# ap_rail_01
# ap_shaft_01
# ap_shaft_upper_01
# ap_sight_01
# ap_stock_01
# ap_underbarrel_01
# j_leftweaponattach
# j_rightweaponattach
# rp_2h_chain_sword_chained_rig
# rp_2h_power_sword_chained_rig
# rp_autogun_ak_chained_rig
# rp_autogun_chained_rig
# rp_autogun_killshot_chained_rig
# rp_autogun_pistol_chained_rig
# rp_blade_01
# rp_bolt_gun_rig
# rp_chain_sword_chained_rig
# rp_club_pipe_chained_rig
# rp_combat_blade_chained_rig
# rp_combat_knife_chained_rig
# rp_combat_sword_chained_rig
# rp_falchion_chained_rig
# rp_flamer_rifle_chained_rig
# rp_force_staff_chained_rig
# rp_force_sword_chained_rig
# rp_gauntlet_basic_chained_rig
# rp_grip_01
# rp_human_power_maul_chained_rig
# rp_lasgun_chained_rig
# rp_lasgun_elysian_chained_rig
# rp_lasgun_krieg_chained_rig
# rp_laspistol_chained_rig
# rp_plasma_rifle_chained_rig
# rp_power_maul_chained_rig
# rp_power_sword_chained_rig
# rp_prologue_shovel_chained_rig
# rp_prologue_shovel_ogryn_chained_rig
# rp_rippergun_rifle_chained_rig
# rp_sabre_chained_rig
# rp_shotgun_grenade_chained_rig
# rp_shotgun_rig
# rp_shovel_chained_rig
# rp_shovel_ogryn_chained_rig
# rp_stubgun_heavy_ogryn_chained_rig
# rp_stubgun_pistol_chained_rig
# rp_thunder_hammer_chained_rig
